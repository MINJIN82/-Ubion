# %% [markdown]
# <a href="https://colab.research.google.com/github/MINJIN82/-Ubion/blob/main/project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Team Project 20230131
# ##유튜브 댓글 텍스트마이닝

# %% [markdown]
# ## 데이터 수집
# ### 크롤링
# ## youtube API V3연동

# %%
# !pip install google-api-python-client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas
from googleapiclient.discovery import build

api_key = "AIzaSyB5xsJPhzhRZl4ONA-3xOYuR-aBZaqo5_s"
video_id = "CjylrN6SrUU"

comments = list()
api_obj = build('youtube', 'v3', developerKey="AIzaSyB5xsJPhzhRZl4ONA-3xOYuR-aBZaqo5_s")
response = api_obj.commentThreads().list(part='snippet,replies', videoId="CjylrN6SrUU", maxResults=100).execute()

while response:
    for item in response['items']:
        comment = item['snippet']['topLevelComment']['snippet']
        comments.append([comment['textDisplay'], comment['authorDisplayName'], comment['publishedAt'], comment['likeCount']])
 
        if item['snippet']['totalReplyCount'] > 0:
            for reply_item in item['replies']['comments']:
                reply = reply_item['snippet']
                comments.append([reply['textDisplay'], reply['authorDisplayName'], reply['publishedAt'], reply['likeCount']])
 
    if 'nextPageToken' in response:
        response = api_obj.commentThreads().list(part='snippet,replies', videoId="CjylrN6SrUU", pageToken=response['nextPageToken'], maxResults=100).execute()
    else:
        break

df = pandas.DataFrame(comments)
df.to_excel('results.xlsx', header=['comment', 'author', 'date', 'num_likes'], index=None)
df
# Out:
#                                                    0            1  \
# 0                   광고를 찾아서 보고....... 기획자님... 승진 각이다  영상 안올라오는 채널
# 1              아~ 사야겠다. 어쩔수가 없구나. 뉴진스님이 광고하는데 사야지 뭐.         주식쟁이
# 2                           아니 노트북 광고가 이렇게 상큼할 일인가 ㅋ  chloe hwang
# 3                        금일자로 lg 그램으로 스타벅스 출입 가능합니다.       Whee -
# 4                     아 진짜 돈 조금만 여유있으면 무조건 사고싶다 그냥..       Whee -
# ...                                              ...          ...
# 1318               드디어 일하기 시작한 마케팅팀!! 새해에는 잘됐으면 좋겠네용        하늘다람쥐
# 1319  @연결 된적 없다 뿌에엥~~~ 여기 누가 정신병원에서 탈주했어요 빨리 와주세요~~~            묭
# 1320                                 남자잖아좀. 웃기지좀 마라ㅋ     연결 된적 없다
# 1321                           제발 당첨됐으면 좋겠다... 제발...   Ban Heesoo
# 1322                                    꼭 갖구싶구만요....         썬sun
#
#                          2   3
# 0     2023-01-31T04:25:17Z   1
# 1     2023-01-30T20:53:28Z   2
# 2     2023-01-30T18:10:29Z   1
# 3     2023-01-30T16:50:07Z   1
# ...

# %% [markdown]
# ##텍스트마이닝

# %%
df_comment = open("/content/drive/MyDrive/Colab Notebooks/data/뉴진스그램comment.txt","rt", encoding="UTF-8").read()
print(df_comment)
# Out:
# 광고를 찾아서 보고....... 기획자님... 승진 각이다
# 아~ 사야겠다. 어쩔수가 없구나. 뉴진스님이 광고하는데 사야지 뭐.
# 아니 노트북 광고가 이렇게 상큼할 일인가 ㅋ
# 금일자로 lg 그램으로 스타벅스 출입 가능합니다.
# 아 진짜 돈 조금만 여유있으면 무조건 사고싶다 그냥..
# New jeans 광고모델 이 것은 매우 최고
# 뉴진스가 사고 싶게끔 만드네
# 오 엘지 일한다!!
# 가볍기 정말 가벼움..
# 헐 개이쁘다 리미티드 에디션 갖고 싶드아ㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏ
# 뉴진스 가보자구요!! 팬싸인회 꼭 가고싶습니다. 요즘 OMG만 듣고있습니다. 뉴진스 X LG 콜라보 화이팅입니다. 뉴진스 노트북 너무 이뻐요!!
# 한정판 200대라던데 에르쥐야 장난하냐? 2000대를 맹글어도 해외팬들까지 경쟁에 끼어들면 광속 매진되겠구만
# 스텔라 장 버전 편곡이네요 ㅎㅎ
# 크 노래랑 너무 잘어울림
# 이러고 뒤에선 맥북쓸거면서!!
# 이거 프로모션 안넣은 영상아니냐? ㅋㅋ 어떻게 조회수 140만 찍은거냐
# 일단 광고 졸라 잘 뽑았고 뉴진스 알고리즘으로 다 알아서 보러 옴
# 광고를 찾아서 보게 만든건 뉴진스가 처음이다,, 갓진스
# 가사로 기능 설명잘해줘서 빌려간사람도 잘앎
# 꼭 갖고 싶네요! :)
# 광고가 이렇게 이쁘고 청량하고 뭉클해?ㅜㅜ
# 뉴진스 그램 갖고싶당~
# 아름다워~ 뉴진스
# <a href="https://www.youtube.com/watch?v=CjylrN6SrUU&amp;t=1m01s">1:01</a> 여기 혜인이 겁나 이쁨
# 사랑해요 강해린
# 너무 이뿌다
# 하 나 진짜 뉴진스때문에 덕질라이프 공개해야겠네…… 인스타 당장 업로드 때린다;
# 삼성보고 왔더니, LG 마케팅 잘하네
# 윤수일님 노래  재탄생이네<br>역시 괜히 1위가수가 아님<br>예전 명곡들 리메이크 앨범하나 부탁해요<br>그램 전면에 토끼한마리 있으면 더 좋습니다
# 광고도 레트로하네 ㅋㅋㅋㅋㅋ
# ...

# %%
df_comment
# Out:
# '광고를 찾아서 보고....... 기획자님... 승진 각이다\n아~ 사야겠다. 어쩔수가 없구나. 뉴진스님이 광고하는데 사야지 뭐.\n아니 노트북 광고가 이렇게 상큼할 일인가 ㅋ\n금일자로 lg 그램으로 스타벅스 출입 가능합니다.\n아 진짜 돈 조금만 여유있으면 무조건 사고싶다 그냥..\nNew jeans 광고모델 이 것은 매우 최고\n뉴진스가 사고 싶게끔 만드네\n오 엘지 일한다!!\n가볍기 정말 가벼움..\n헐 개이쁘다 리미티드 에디션 갖고 싶드아ㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏㅏ\n뉴진스 가보자구요!! 팬싸인회 꼭 가고싶습니다. 요즘 OMG만 듣고있습니다. 뉴진스 X LG 콜라보 화이팅입니다. 뉴진스 노트북 너무 이뻐요!!\n한정판 200대라던데 에르쥐야 장난하냐? 2000대를 맹글어도 해외팬들까지 경쟁에 끼어들면 광속 매진되겠구만\n스텔라 장 버전 편곡이네요 ㅎㅎ\n크 노래랑 너무 잘어울림\n이러고 뒤에선 맥북쓸거면서!!\n이거 프로모션 안넣은 영상아니냐? ㅋㅋ 어떻게 조회수 140만 찍은거냐\n일단 광고 졸라 잘 뽑았고 뉴진스 알고리즘으로 다 알아서 보러 옴\n광고를 찾아서 보게 만든건 뉴진스가 처음이다,, 갓진스\n가사로 기능 설명잘해줘서 빌려간사람도 잘앎\n꼭 갖고 싶네요! :)\n광고가 이렇게 이쁘고 청량하고 뭉클해?ㅜㅜ\n뉴진스 그램 갖고싶당~\n아름다워~ 뉴진스\n<a href="https://www.youtube.com/watch?v=CjylrN6SrUU&amp;t=1m01s">1:01</a> 여기 혜인이 겁나 이쁨\n사랑해요 강해린\n너무 이뿌다\n하 나 진짜 뉴진스때문에 덕질라이프 공개해야겠네…… 인스타 당장 업로드 때린다;\n삼성보고 왔더니, LG 마케팅 잘하네\n윤수일님 노래  재탄생이네<br>역시 괜히 1위가수가 아님<br>예전 명곡들 리메이크 앨범하나 부탁해요<br>그램 전면에 토끼한마리 있으면 더 좋습니다\n광고도 레트로하네 ㅋㅋㅋㅋㅋ\n뉴진스가 아깝다<br>BGM이랑 광고랑 에효 이걸 ok한놈도 문제고\n
# ...

# %% [markdown]
# ##클래스 별 키워드 추출
# ### Hannanum(카이스트 클래스), Kkma(서울대학교 클래스),Okt(오픈소스)

# %%
# !pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 56.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.6/465.6 KB 40.8 MB/s eta 0:00:00
# ...

# %%
from konlpy.tag import Kkma, Okt, Komoran, Hannanum
from konlpy.utils import pprint
from collections import Counter

# %%
#Okt 객체 생성_과거 트위터 형태소, 오픈 소스
okt = Okt()
noun = okt.nouns(df_comment)

count = Counter(noun)

#명사 빈도 카운트
noun_list = count.most_common(200)
for v in noun_list : 
    print("Okt 기준 : " +str(v))
# Out:
# Okt 기준 : ('뉴진스', 244)
# Okt 기준 : ('광고', 151)
# Okt 기준 : ('그램', 102)
# Okt 기준 : ('노래', 75)
# Okt 기준 : ('진짜', 72)
# Okt 기준 : ('노트북', 68)
# Okt 기준 : ('엘지', 42)
# Okt 기준 : ('에디', 36)
# Okt 기준 : ('션', 36)
# Okt 기준 : ('거', 34)
# Okt 기준 : ('일', 31)
# Okt 기준 : ('스텔라', 28)
# Okt 기준 : ('맥북', 28)
# Okt 기준 : ('곡', 27)
# Okt 기준 : ('마케팅', 26)
# Okt 기준 : ('사고', 25)
# Okt 기준 : ('해린', 23)
# Okt 기준 : ('좀', 22)
# Okt 기준 : ('모델', 19)
# Okt 기준 : ('이', 17)
# Okt 기준 : ('토끼', 17)
# Okt 기준 : ('제품', 17)
# Okt 기준 : ('팀', 17)
# Okt 기준 : ('왜', 17)
# Okt 기준 : ('가격', 17)
# Okt 기준 : ('생각', 17)
# Okt 기준 : ('목소리', 16)
# Okt 기준 : ('뭐', 15)
# Okt 기준 : ('리미', 15)
# Okt 기준 : ('역시', 15)
# Okt 기준 : ('최고', 14)
# Okt 기준 : ('개', 14)
# Okt 기준 : ('영상', 14)
# Okt 기준 : ('사랑', 14)
# Okt 기준 : ('이건', 14)
# Okt 기준 : ('디자인', 14)
# Okt 기준 : ('음원', 14)
# Okt 기준 : ('임', 14)
# Okt 기준 : ('때', 14)
# Okt 기준 : ('느낌', 14)
# Okt 기준 : ('뉴진', 13)
# Okt 기준 : ('것', 13)
# Okt 기준 : ('팬', 13)
# Okt 기준 : ('처음', 13)
# Okt 기준 : ('사람', 13)
# ...

# %%
#Kkma 객체 생성_서울대학교
okt = Kkma()
noun = okt.nouns(df_comment)

count = Counter(noun)

#명사 빈도 카운트
noun_list = count.most_common(200)
for v in noun_list : 
    print("Kkma 기준 : " +str(v))
# Out:
# Kkma 기준 : ('대', 3)
# Kkma 기준 : ('위', 3)
# Kkma 기준 : ('구', 3)
# Kkma 기준 : ('년', 3)
# Kkma 기준 : ('분', 3)
# Kkma 기준 : ('이', 3)
# Kkma 기준 : ('일', 2)
# Kkma 기준 : ('그램', 2)
# Kkma 기준 : ('뉴진스', 2)
# Kkma 기준 : ('오', 2)
# Kkma 기준 : ('개', 2)
# Kkma 기준 : ('디', 2)
# Kkma 기준 : ('만', 2)
# Kkma 기준 : ('건', 2)
# Kkma 기준 : ('갓', 2)
# Kkma 기준 : ('갓진스', 2)
# Kkma 기준 : ('하', 2)
# Kkma 기준 : ('님', 2)
# Kkma 기준 : ('명', 2)
# Kkma 기준 : ('삼', 2)
# Kkma 기준 : ('하나', 2)
# Kkma 기준 : ('굿즈', 2)
# Kkma 기준 : ('원', 2)
# Kkma 기준 : ('국', 2)
# Kkma 기준 : ('바', 2)
# Kkma 기준 : ('해린', 2)
# Kkma 기준 : ('씨', 2)
# Kkma 기준 : ('지', 2)
# Kkma 기준 : ('언제', 2)
# Kkma 기준 : ('터', 2)
# Kkma 기준 : ('등', 2)
# Kkma 기준 : ('투', 2)
# Kkma 기준 : ('내', 2)
# Kkma 기준 : ('둘', 2)
# Kkma 기준 : ('여', 2)
# Kkma 기준 : ('쪽', 2)
# Kkma 기준 : ('번', 2)
# Kkma 기준 : ('광고', 1)
# Kkma 기준 : ('보고', 1)
# Kkma 기준 : ('기획자', 1)
# Kkma 기준 : ('승진', 1)
# Kkma 기준 : ('각', 1)
# Kkma 기준 : ('사야', 1)
# Kkma 기준 : ('수', 1)
# Kkma 기준 : ('뉴', 1)
# Kkma 기준 : ('뉴진스님', 1)
# ...

# %%
#Hannanum 객체 생성_카이스트
okt = Hannanum()
noun = okt.nouns(df_comment)

count = Counter(noun)

#명사 빈도 카운트
noun_list = count.most_common(200)
for v in noun_list :
    print("Hannanum  기준 : " +str(v))
# Out:
# Hannanum  기준 : ('뉴진스', 208)
# Hannanum  기준 : ('광고', 129)
# Hannanum  기준 : ('그램', 78)
# Hannanum  기준 : ('진짜', 68)
# Hannanum  기준 : ('노래', 64)
# Hannanum  기준 : ('노트북', 61)
# Hannanum  기준 : ('것', 40)
# Hannanum  기준 : ('일', 31)
# Hannanum  기준 : ('에디션', 28)
# Hannanum  기준 : ('ㅋㅋ', 24)
# Hannanum  기준 : ('ㅠㅠ', 20)
# Hannanum  기준 : ('ㅋ', 18)
# Hannanum  기준 : ('데', 18)
# Hannanum  기준 : ('스텔라장', 18)
# Hannanum  기준 : ('이', 18)
# Hannanum  기준 : ('맥북', 18)
# Hannanum  기준 : ('❤', 18)
# Hannanum  기준 : ('나', 17)
# Hannanum  기준 : ('지', 16)
# Hannanum  기준 : ('제품', 15)
# Hannanum  기준 : ('생각', 15)
# Hannanum  기준 : ('리미티드', 14)
# Hannanum  기준 : ('이거', 14)
# Hannanum  기준 : ('ㅋㅋㅋㅋㅋ', 14)
# Hannanum  기준 : ('.', 14)
# Hannanum  기준 : ('목소리', 14)
# Hannanum  기준 : ('듯', 14)
# Hannanum  기준 : ('수', 13)
# Hannanum  기준 : ('디자인', 13)
# Hannanum  기준 : ('모델', 13)
# Hannanum  기준 : ('뭐', 13)
# Hannanum  기준 : ('마케팅', 12)
# Hannanum  기준 : ('ㅋㅋㅋ', 12)
# Hannanum  기준 : ('가격', 12)
# Hannanum  기준 : ('폼', 12)
# ...

# %% [markdown]
# ##워드클라우드_교수님 알려주신 코드

# %%
from wordcloud import WordCloud

# %%
okt = Okt() #Okt 함수 삽입
line = []

line = okt.pos(df_comment) #품사 삽입
n_adj =[]
for word, tag in line: #워드에 태그를 붙여줘
    if tag in ["Noun","Adjective"]: #명사랑 형용사만 뽑을게
      n_adj.append(word)
print(n_adj) #리스트 안에 명사,형용사
# Out:
# ['광고', '보고', '기획', '자', '승진', '각', '수가', '없구나', '뉴진', '스님', '광고', '뭐', '아니', '노트북', '광고', '상큼', '일인', '금일', '그램', '스타벅스', '출입', '가능합니다', '진짜', '돈', '조금', '여유', '있으면', '무조건', '그냥', '광고', '모델', '이', '것', '매우', '최고', '뉴진스', '사고', '만드', '오', '엘지', '일', '가볍기', '정말', '가벼', '움', '개', '이쁘다', '리미', '티드', '에디', '션', '싶드', '뉴진스', '팬싸인회', '꼭', '요즘', '만', '뉴진스', '콜라보', '화이팅', '입니다', '뉴진스', '노트북', '이뻐요', '한정판', '던데', '에르', '쥐', '장난', '맹글어', '해외', '팬', '경쟁', '광속', '매진', '스텔라', '장', '버전', '편곡', '요', '노래', '뒤', '맥북', '거', '프로모션', '영상', '아니냐', '어떻게', '회수', '일단', '광고', '졸라', '뉴진스', '알고리즘', '옴', '광고', '뉴진스', '처음', '갓진스', '가사', '기능', '설명', '간', '사람', '꼭', '광고', '이쁘고', '청량하고', '뭉클해', '뉴진스', '그램', '아름다워', '뉴진스', '여기', '혜인', '이쁨', '사랑', '강', '해린', '이뿌다', '나', '진짜', '뉴진스때문', '덕질', '라이프', '공개', '인스타', '당장', '업로드', '성보고', '마케팅', '윤수일', '노래', '재탄생', '역시', '위', '가수', '아님', '예전', '명곡', '리메이크', '앨범', '하나', '부탁', '그램', '전면', '토끼', '마리', '있으면', '더', '좋습니다', '광고', '레트로', '뉴진스', '아깝다', '광고', '효', '걸', '놈', '문제', '론데',
# ...

# %%
counts = Counter(n_adj)
tags = counts.most_common(50)
print(counts)
print(tags)
# Out:
# Counter({'뉴진스': 244, '광고': 151, '그램': 102, '노래': 75, '진짜': 72, '노트북': 68, '엘지': 42, '에디': 36, '션': 36, '거': 34, '스텔라': 28, '맥북': 28, '곡': 27, '마케팅': 26, '사고': 25, '아름다워': 25, '해린': 23, '좀': 22, '모델': 19, '이': 17, '토끼': 17, '제품': 17, '팀': 17, '왜': 17, '가격': 17, '생각': 17, '이쁘다': 16, '목소리': 16, '뭐': 15, '리미': 15, '역시': 15, '최고': 14, '개': 14, '영상': 14, '사랑': 14, '이건': 14, '디자인': 14, '음원': 14, '미쳤다': 14, '때': 14, '느낌': 14, '뉴진': 13, '것': 13, '팬': 13, '처음': 13, '사람': 13, '더': 13, '전자': 13, '티드': 12, '윤수일': 12, '민지': 12, '폼': 12, '대박': 12, '저': 12, '오': 11, '나': 11, '레트로': 11, '걸': 11, '예쁘다': 11, '보고': 10, '아니': 10, '한정판': 10, '스랑': 10, '좋다': 10, '대세': 10, '세상': 10, '말': 10, '멤버': 10, '버전': 9, '요': 9, '여기': 9, '하나': 9, '중': 9, '하니': 9, '이번': 9, '돈': 8, '강': 8, '또': 8, '굿': 8, '제대로': 8, '이쁘네': 8, '이뻐': 8, '삼성': 8, '그': 8, '귀여워': 8, '아이폰': 8, '수': 8, '그냥': 7, '정말': 7, '꼭': 7, '요즘': 7, '콜라보': 7, '위': 7, '리메이크': 7, '시티': 7, '팝': 7, '감성': 7, '우리': 7, '내': 7, '이제': 7, '아름다운': 7, '지금': 7, '기획': 6,
# ...

# %%
from wordcloud import WordCloud

# %%
#불필요한(불용어어) 문자 삭제
stop_words = " 개, 강, 중,요, 수, 그, 시티,위,팀,또,이, 스랑, 함,오, 팝, 강, 더, 일, 임, 개"
stop_words = set(stop_words.split(" "))
n_adj = [word for word in n_adj if not word in stop_words]

# %%
font ="/content/drive/MyDrive/malgun.ttf"
word_cloud = WordCloud(font_path=font, background_color="white",max_font_size=300, colormap="prism").generate_from_frequencies(dict(tags))
import matplotlib.pyplot as plt
plt.figure(figsize = (50,8))
plt.imshow(word_cloud)
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)
